# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import urllib.request
import time

# %%
authors = []
dates = []
statements = []
sources = []
targets = []

# %%
def scrape_website(page_number):
  page_num = str(page_number)
  URL = 'https://www.politifact.com/factchecks/list/?page='+page_num
  webpage = requests.get(URL)
  soup = BeautifulSoup(webpage.text, 'html.parser')
  statement_footer = soup.find_all ('footer' , attrs={'class' : 'm-statement__footer'})
  statement_quote = soup.find_all ('div' , attrs={'class' : 'm-statement__quote'})
  statement_meta = soup.find_all ('div' , attrs={'class' : 'm-statement__meta'})
  target = soup.find_all ('div' , attrs={'class' : 'm-statement__meter'})

  for i in statement_footer:
    link1 = i.text.strip()
    name_and_date= link1.split()
    first_name = name_and_date[1]
    last_name = name_and_date[2]
    full_name = first_name + ' ' + last_name
    month = name_and_date[4]
    day = name_and_date[5]
    year = name_and_date[6]
    date = month+' '+day+' '+year
    dates.append(date)
    authors.append(full_name)   

  for i in statement_quote:
    link2 = i.find_all('a')
    statement_text = link2[0].text.strip()
    statements.append(statement_text)

  for i in statement_meta:
    link3 = i.find_all('a')
    source_text = link3[0].text.strip()
    sources.append(source_text)

  for i in target:
    link4 = i.find('div' , attrs={'class' : 'c-image'}).find('img').get('alt')
    targets.append(link4)

# %%
n = 2
for i in range(1, n):
  scrape_website(i)

# %%
data = pd.DataFrame(columns = ['author','statement','source','date','target'])
data['author']= authors
data['statement']= statements
data['source']= sources
data['date']= dates
#data['target']= targets

# %%
def  getBinaryNumTarget(text):
     if text == 'true' :
       return 1
     else:
       return 0

# %%
def  getBinaryTarget(text):
     if text == 'true' :
       return 'REAL'
     else:
       return 'FAKE'

# %%
data['BinaryTarget']= data['target'].apply(getBinaryTarget)
data['BinaryNumTarget']= data['target'].apply(getBinaryTarget)

# %%
data
# Out:
#                  author  ... BinaryNumTarget
# 0            Eric Litke  ...            FAKE
# 1    Samantha Putterman  ...            FAKE
# 2        Louis Jacobson  ...            FAKE
# 3         Bill McCarthy  ...            FAKE
# 4   Eleanor Hildebrandt  ...            FAKE
# 5        Ciara O'Rourke  ...            FAKE
# 6         Monique Curet  ...            FAKE
# 7            Eric Litke  ...            FAKE
# 8        Brandon Mulder  ...            FAKE
# 9        Haley BeMiller  ...            FAKE
# 10        Tom Kertscher  ...            FAKE
# 11        Tom Kertscher  ...            FAKE
# 12       Ciara O'Rourke  ...            FAKE
# 13         Daniel Funke  ...            FAKE
# 14       Louis Jacobson  ...            FAKE
# 15     Jessica Calefati  ...            FAKE
# 16        Bill McCarthy  ...            FAKE
# 17              Noah Y.  ...            FAKE
# 18     Brooklyn Draisey  ...            FAKE
# 19       Ciara O'Rourke  ...            FAKE
# 20           Eric Litke  ...            FAKE
# 21         Daniel Funke  ...            FAKE
# 22    Clara Hendrickson  ...            FAKE
# 23              Noah Y.  ...            FAKE
# 24        Jon Greenberg  ...            FAKE
# 25   Samantha Putterman  ...            FAKE
# 26         Daniel Funke  ...            FAKE
# 27     Veronica Mohesky  ...            FAKE
# 28       Ciara O'Rourke  ...            FAKE
# 29         Jill Terreri  ...            FAKE
# 30           Eric Litke  ...            FAKE
# 31   Samantha Putterman  ...            FAKE
# 32       Louis Jacobson  ...            FAKE
# 33        Bill McCarthy  ...            FAKE
# 34  Eleanor Hildebrandt  ...            FAKE
# 35       Ciara O'Rourke  ...            FAKE
# 36        Monique Curet  ...            FAKE
# 37           Eric Litke  ...            FAKE
# 38       Brandon Mulder  ...            FAKE
# 39       Haley BeMiller  ...            FAKE
# 40        Tom Kertscher  ...            FAKE
# 41        Tom Kertscher  ...            FAKE
# 42       Ciara O'Rourke  ...            FAKE
# 43         Daniel Funke  ...            FAKE
# 44       Louis Jacobson  ...            FAKE
# 45     Jessica Calefati  ...            FAKE
# 46        Bill McCarthy  ...            FAKE
# 47              Noah Y.  ...            FAKE
# 48     Brooklyn Draisey  ...            FAKE
# 49       Ciara O'Rourke  ...            FAKE
# 50           Eric Litke  ...            FAKE
# 51         Daniel Funke  ...            FAKE
# 52    Clara Hendrickson  ...            FAKE
# 53              Noah Y.  ...            FAKE
# 54        Jon Greenberg  ...            FAKE
# 55   Samantha Putterman  ...            FAKE
# 56         Daniel Funke  ...            FAKE
# 57     Veronica Mohesky  ...            FAKE
# 58       Ciara O'Rourke  ...            FAKE
# 59         Jill Terreri  ...            FAKE
#
# [60 rows x 7 columns]

# %%
#data.to_csv(fact_checker.csv)
